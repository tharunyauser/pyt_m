# %% [markdown]
# 1. Hello World
# Prints a welcome message.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# 2. Add Two Numbers
# Adds two numbers and prints the result.

# %%
a,b=10,20
sum=a+b
print(f"sum of {a} and {b} is {sum}")
print("sum of a and b is:",sum)
# Out:
# sum of 10 and 20 is 30
# sum of a and b is: 30

# %% [markdown]
# 3. Simple Interest Calculator
# Calculates simple interest using the formula.
# This applies the basic formula for calculating interest over time.

# %%
#SI=(PTR)/100
principle=100000
time=24      #2 years
rate=1         #1% per month i.e, (100000/100 )=1000
simple_interest=(principle*time*rate)/100
print("simple interest is ",simple_interest)
# Out:
# simple interest is  24000.0

# %% [markdown]
# 4. Average of Three Numbers
# Finds the average of three numbers.
# The program calculates the average by summing and dividing the values.

# %%
# Calculate average of three values
x = 60
y = 75
z = 90
average = (x + y + z) / 3
print("Average:", average)
# Out:
# Average: 75.0

# %% [markdown]
# 5. TEMPERATURE SCALES
#
# Freezing point of water: 0 °C = 32 °F = 273.15 K
#
# Boiling point of water: 100 °C = 212 °F = 373.15 K
#
# Absolute zero: −273.15 °C = −459.67 °F = 0 K
#
#
# Celsius (°C)     -> 	Fahrenheit (°F)	  -> Kelvin (K)
#
# 0	       ->     32	     ->      273.15
#
# 10	        ->        50	   ->        283.15
#
# 20	       ->          68	    ->       293.15
#
# 30	        ->        86	   ->        303.15

# %% [markdown]
# 🔑 Key Points
# Celsius ↔ Kelvin is a simple offset (+273.15).
#
# Celsius ↔ Fahrenheit involves scaling (×9/5 or ×5/9) plus an offset (±32).
#
# Fahrenheit ↔ Kelvin combines both scaling and offset.
#
#
#
# 1.)  Celsius to Fahrenheit  (trick to increase by ((5/9)>1 and +32) as |^ C to F):
#
#           F=(9/5)C + 32
#
#     celsius to kelvin  (trick:as easy conversion)

# %%
print("Celsius °C \t Fahrenheit °F \t Kelvin K \n 0      \t 32	 \t 273.1\n ")
# Out:
# Celsius °C 	 Fahrenheit °F 	 Kelvin K
#  0      	 32	 	 273.1

# %% [markdown]
# Celsius ↔ Kelvin is a simple offset (+273.15).
#
# Celsius ↔ Fahrenheit involves scaling (×9/5 or ×5/9) plus an offset (±32).
#
# Fahrenheit ↔ Kelvin combines both scaling and offset.
