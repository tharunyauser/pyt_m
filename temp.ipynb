# %%
list =(3, 4, 5)
print(list)
# Out:
# (3, 4, 5)

# %%
list.append(6)
print(len(list))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 list.append(6)
#       2 print(len(list))
#
# AttributeError: 'tuple' object has no attribute 'append'
