# %% [markdown]
# ### Syntax and Semantics in Python
# Video Outline:
# - Single line Comments and multiline comments
# - Definition of Syntax and Semantics
# - Basic Syntax Rules in Python
# - Understanding Semantics in Python
# - Common Syntax Errors and How to Avoid Them
# - Practical Code Examples

# %% [markdown]
# Syntax refers to the set of rules that defines the combinations of symbols that are considered to be correctly structured programs in a language. In simpler terms, syntax is about the correct arrangement of words and symbols in a code.
#
# Semantics refers to the meaning or the interpretation of the symbols, characters, and commands in a language. It is about what the code is supposed to do when it runs.

# %% [markdown]
# ### my understanding:
# Syntax: it is defined by set of rules . It focuses the code be properly structured according to the programming lang. correctly arranging the symbols and words in the code.
#
# Semantic:the code which we written should had some meaningful. we shld know what code should does when it runs or executes.

# %% [markdown]
# ex: (not sure it is correct)
# naming a variable by using rules like(shldn't start with number or special chara etc.,)   ->syntax
# naming the same variable with proper name according to context by fwg some rules  ->semantic

# %%
## Basic Syntax Rules In Python
## Case sensitivity- Python is case sensitive

name="Krish"
Name="Naik"

print(name)
print(Name)
# Out:
# Krish
# Naik

# %% [markdown]
# ### Indentation
# Indentation in Python is used to define the structure and hierarchy of the code. Unlike many other programming languages that use braces {} to delimit blocks of code, Python uses indentation to determine the grouping of statements. This means that all the statements within a block must be indented at the same level.

# %%
## Indentation
## Python uses indentation to define blocks of code. Consistent use of spaces (commonly 4) or a tab is required.

age=32
if age>30: 
    print(age) # it is under indent to the if block
    
print(age)   #This stmt is not belongs to the if block bcoz it doesn't follow the indentation
# Out:
# 32
# 32

# %%
## This is a single line comment
# Double hash (##) is also valid for singl e line comments
print("Hello World")
# Out:
# Hello World

# %%
## Line Continuation
##Use a backslash (\) to continue a statement to the next line , after\ nthg shld be present even space too.

total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## Multiple Statements on a single line      
# here we used semicolon(;)
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
##Understand  Semantics In Python
# variable assignment
age=32                                ##age is an integer
name="Krish"                           ##name is a string



## unlike in other pgm'ng langs we didn't mention the type of  data type to a variable before assignment,
## in python, kernel can understand the type of data type while runinng the lines of code

# %%
type(age)
# Out:
# int

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
## Type Inference
variable=10
print(type(variable))
## dynamically we can change the type of variables (here :int-> str)
variable="Krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## indenation is more matters in python programming lang
age=32
if age>30:
    print(age)


##  we use indentaion in loops, conditons, clases, oops etc.,,,
# Out:
# 32

# %%
## Name Error
a=b      ## here b is not defined


## to handle it & more, we can check it in exception handling
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 ## Name Error
# ----> 2 a=b      ## here b is not defined
#
# NameError: name 'b' is not defined

# %%
## Code exmaples of indentation
if True:
    print("Correct Indentation")     #True is a boolean variable 
    if False:
        print("This one print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block

# %%
#from github copilot
# Check if all syntax and semantics topics were covered, if not please provide them 


syntax_topics = [
    "Single line comments",
    "Multiline comments",
    "Definition of Syntax",
    "Basic Syntax Rules",
    "Case sensitivity",
    "Indentation",
    "Line continuation",
    "Multiple statements on a single line",
    "Common Syntax Errors"
]

semantics_topics = [
    "Definition of Semantics",
    "Variable assignment",
    "Type inference",
    "Type checking",
    "Meaning of code execution"
]

covered = {
    "Single line comments": any("#" in cell for cell in [open(__file__).read()]),  # simulated check
    "Multiline comments": False,  # Not explicitly shown in the notebook
    "Definition of Syntax": True,
    "Basic Syntax Rules": True,
    "Case sensitivity": True,
    "Indentation": True,
    "Line continuation": True,
    "Multiple statements on a single line": True,
    "Common Syntax Errors": True,  # NameError example
    "Definition of Semantics": True,
    "Variable assignment": True,
    "Type inference": True,
    "Type checking": True,
    "Meaning of code execution": True
}

missing = [topic for topic, is_covered in covered.items() if not is_covered]

if missing:
    print("The following topics were not covered:")
    for topic in missing:
        print("-", topic)
    # Example for multiline comments
    print("\nExample of multiline comments in Python:")
    print('''"""This is a
multiline comment
in Python."""''')
else:
    print("All syntax and semantics topics were covered in this notebook.")

# %% [markdown]
# ### Conclusion:
# Understanding the syntax and semantics of Python is crucial for writing correct and meaningful programs. Syntax ensures the code is properly structured, while semantics ensures the code behaves as expected. Mastering these concepts will help in writing efficient and error-free Python code.
